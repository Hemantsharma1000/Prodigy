# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemantsharma1000/Prodigy/blob/main/sentiment_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your training and validation datasets
train_data = pd.read_csv('/content/twitter_training.csv')

# %%
# Handle missing values in the dataset
train_data = train_data.dropna()  # Drop rows with missing values

# %%
# Split the data into features (text) and labels (sentiment)
X_train = train_data['text']
y_train = train_data['Sentiment']

# %%
# Step 2: Text Vectorization
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)

# %%
# Step 3: Sentiment Analysis (Using Naive Bayes as an example)
model = MultinomialNB()
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
# Step 4: Evaluate the model
accuracy = accuracy_score(y_val, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8248248248248248

# %%
# Step 5: Visualize the sentiment distribution
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x='Sentiment', data=train_data, palette="Set2")
plt.title("Sentiment Distribution in Training Data")
plt.show()

# %%
# Load new data for prediction
new_data = pd.read_csv('/content/twitter_validation.csv')

# %%
# Handle missing values in the new data
new_data = new_data.dropna()  # Drop rows with missing values

# Extract the text features from the new data
X_new = new_data['text']

# %%
# Vectorize the text in the new data using the same vectorizer
X_new_vec = vectorizer.transform(X_new)

# %%
# Predict sentiment using the trained model
y_pred_new = model.predict(X_new_vec)

# Add the predicted sentiment to the new data DataFrame
new_data['predicted_sentiment'] = y_pred_new

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='predicted_sentiment', data=new_data, palette="Set2")
plt.title("Predcted Sentiment Distribution in New Data")
plt.show()
